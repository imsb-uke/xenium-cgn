# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq

from tqdm import tqdm
import json

import matplotlib.pyplot as plt
import seaborn as sns

from torch_geometric.nn import MessagePassing
import scipy
import torch_geometric as pyg
import torch
from torch_geometric.data import Data, Batch

from src.utils_nichepca import *
from src.utilities import *
from scipy.signal import find_peaks

import warnings
warnings.filterwarnings('ignore')

# %%
save_path = "data/"
data_path = "/data/projects/robin/segmentation/xenium_outs/merged_processed_cleaned.h5ad"

# %%
# Read data
adata = sc.read_h5ad(data_path)
del adata.layers['counts']

# %%
adata.obs['sample'] = [i.split('_')[0] for i in adata.obs['Patient_Sample_ID']]
sample_set = adata.obs['sample'].unique()
sample_set
# Out:
# array(['X40', 'X39', 'X38', 'X37', 'X36', 'X35', 'X34', 'X33', 'X63',
#        'X61', 'X62', 'X60', 'X59', 'X58', 'X57', 'X32', 'X31', 'X30',
#        'X29', 'X28', 'X27', 'X26', 'X25', 'X56', 'X55', 'X54', 'X53',
#        'X52', 'X50', 'X51', 'X49', 'X8', 'X7', 'X6', 'X4', 'X5', 'X2',
#        'X3', 'X1', 'X48', 'X47', 'X46', 'X45', 'X44', 'X43', 'X42', 'X41',
#        'X16', 'X15', 'X14', 'X12', 'X13', 'X11', 'X10', 'X9', 'X24',
#        'X23', 'X22', 'X21', 'X20', 'X19', 'X18', 'X17'], dtype=object)

# %%
# run domain pca
for sample in tqdm(sample_set):
    
    print(sample)
    
    adata_sample = adata[adata.obs['sample'] == sample].copy()
    run_domain_pca(adata_sample, knn=None, radius=20, n_comps=30, preprocess=False)

    resolutions = np.arange(0.03, 0.4, 0.02)
    resolutions = resolutions.round(4).tolist()
    sc.pp.neighbors(adata_sample, use_rep="X_pca")
    adata_sample, _ = multiple_lediden(adata_sample, resolutions, key_added='leiden', n_jobs=20, verbos=False)

    # adata_sample.write_h5ad(f"data/adata_nichepca_sample_{sample}_clustered.h5ad")
    adata_sample.write_h5ad(f"/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_dist/adata_nichepca_sample_{sample}_clustered.h5ad")
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]
# X40
# ----------- Graph Stats -----------
# Number of nodes: 31336
# Number of edges: 367316
# Average in-degree: 11.721853256225586
# Average out-degree: 11.721853256225586
# Contains self-loops: True
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
#   2%|▏         | 1/63 [04:03<4:11:20, 243.23s/it]
# X39
# ----------- Graph Stats -----------
# Number of nodes: 103583
# Number of edges: 1590413
# Average in-degree: 15.353996276855469
# Average out-degree: 15.353996276855469
# Contains self-loops: True
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
#   3%|▎         | 2/63 [11:40<6:15:22, 369.21s/it]
# X38
# ----------- Graph Stats -----------
# Number of nodes: 40527
# Number of edges: 593705
# Average in-degree: 14.649616241455078
# Average out-degree: 14.649616241455078
# Contains self-loops: True
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
#   5%|▍         | 3/63 [18:00<6:13:56, 373.95s/it]
# X37
# ----------- Graph Stats -----------
# Number of nodes: 53355
# Number of edges: 844133
# Average in-degree: 15.821066856384277
# Average out-degree: 15.821066856384277
# Contains self-loops: True
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
#   6%|▋         | 4/63 [24:17<6:09:10, 375.42s/it]
# X36
# ----------- Graph Stats -----------
# Number of nodes: 54631
# Number of edges: 841783
# Average in-degree: 15.408522605895996
# Average out-degree: 15.408522605895996
# Contains self-loops: True
#   8%|▊         | 5/63 [29:04<5:32:02, 343.49s/it]
# X35
# ----------- Graph Stats -----------
# Number of nodes: 32350
# Number of edges: 408788
# Average in-degree: 12.636414527893066
# Average out-degree: 12.636414527893066
# Contains self-loops: True
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
# /data/projects/Behnam/xenium-cgn/notebooks/06_domain_identification/src/utilities.py:42: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = r, key_added = key_added + "_res_" + str(r), random_state = random_state)
#  10%|▉         | 6/63 [34:05<5:12:21, 328.79s/it]
# X34
# ----------- Graph Stats -----------
# Number of nodes: 69153
# Number of edges: 1128175
# Average in-degree: 16.31418800354004
# Average out-degree: 16.31418800354004
# Contains self-loops: True

# %%
print('end')
# Out:
# end
