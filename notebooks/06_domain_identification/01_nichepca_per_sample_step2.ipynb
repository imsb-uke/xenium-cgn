# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq

from tqdm import tqdm
import json

import matplotlib.pyplot as plt
import seaborn as sns

from torch_geometric.nn import MessagePassing
import scipy
import torch_geometric as pyg
import torch
from torch_geometric.data import Data, Batch

from src.utils_nichepca import *
import src.utilities as utils
from scipy.signal import find_peaks

import warnings
warnings.filterwarnings('ignore')

# %%
resolutions = np.arange(0.03, 0.4, 0.02)
resolutions = resolutions.round(4).tolist()

# %%
save_path = "data/"
data_path_1 = "/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_knn/"
data_path_2 = "/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_dist/"

# %%
# Read data
sample = 'X5'
adata_1 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")

# %%
resolution_best = resolutions[18]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_1,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_1.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.39

# %%
# Read data
sample = 'X26'
adata_2 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_2,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_2.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'X63'
adata_3 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")

# %%
resolution_best = resolutions[10]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_3,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_3.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.23

# %%
# Read data
sample = 'X64'
adata_4 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[339], line 3
#       1 # Read data
#       2 sample = 'X64'
# ----> 3 adata_4 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")
#
# File ~/envs/ssc/lib/python3.11/site-packages/anndata/_io/h5ad.py:237, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     229         raise NotImplementedError(
#     230             "Currently only `X` and `raw/X` can be read as sparse."
#     231         )
#     233 rdasp = partial(
#     234     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     235 )
# --> 237 with h5py.File(filename, "r") as f:
#     239     def callback(func, elem_name: str, elem, iospec):
#     240         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File ~/envs/ssc/lib/python3.11/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~/envs/ssc/lib/python3.11/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_knn/adata_nichepca_sample_X64_clustered.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
resolution_best = resolutions[18]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_4,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_4.uns.pop(f'leiden_res_{resolution_best}_colors');

# %%
# Read data
sample = 'X65'
adata_5 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[342], line 3
#       1 # Read data
#       2 sample = 'X65'
# ----> 3 adata_5 = sc.read_h5ad(data_path_1 + f"adata_nichepca_sample_{sample}_clustered.h5ad")
#
# File ~/envs/ssc/lib/python3.11/site-packages/anndata/_io/h5ad.py:237, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     229         raise NotImplementedError(
#     230             "Currently only `X` and `raw/X` can be read as sparse."
#     231         )
#     233 rdasp = partial(
#     234     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     235 )
# --> 237 with h5py.File(filename, "r") as f:
#     239     def callback(func, elem_name: str, elem, iospec):
#     240         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File ~/envs/ssc/lib/python3.11/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~/envs/ssc/lib/python3.11/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_knn/adata_nichepca_sample_X65_clustered.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
resolution_best = resolutions[10]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_5,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_5.uns.pop(f'leiden_res_{resolution_best}_colors');
