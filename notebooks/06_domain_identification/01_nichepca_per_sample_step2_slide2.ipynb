# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq

from tqdm import tqdm
import json

import matplotlib.pyplot as plt
import seaborn as sns

from torch_geometric.nn import MessagePassing
import scipy
import torch_geometric as pyg
import torch
from torch_geometric.data import Data, Batch

from src.utils_nichepca import *
import src.utilities as utils
from scipy.signal import find_peaks

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
resolutions = np.arange(0.03, 0.4, 0.02)
resolutions = resolutions.round(4).tolist()

# %%
save_path = "data/"
data_path_1 = "/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_knn/"
data_path_2 = "/projectbig/jupyternotebook/xenium_cgn/domain_identification_from_epyc/per_sample_dist/"

# %%
# Read data
sample = 'x1'
adata_1 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_1,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_1.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'x2'
adata_2 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_2,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_2.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'x3'
adata_3 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_3,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_3.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'x4'
adata_4 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_4,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_4.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'x5'
adata_5 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[10]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_5,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_5.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.23

# %%
adata_5.obs['ispec'] = adata_5.obs['celltype_l1'] == 'PEC'

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_5,
    library_id="spatial",
    shape=None,
    color="ispec,
    wspace=0.1,
    ax = ax
)

# %%
# Read data
sample = 'x6'
adata_6 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_6,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_6.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
# Read data
sample = 'x7'
adata_7 = sc.read_h5ad(data_path_2 + f"adata_nichepca_sample_{sample}_clustered_slide2_with_Ki67.h5ad")

# %%
resolution_best = resolutions[5]
print(resolution_best)

fig, ax = plt.subplots(figsize=(8, 8))

sq.pl.spatial_scatter(
    adata_7,
    library_id="spatial",
    shape=None,
    color="leiden_res_"+str(resolution_best),
    wspace=0.1,
    ax = ax
)

adata_7.uns.pop(f'leiden_res_{resolution_best}_colors');
# Out:
# 0.13

# %%
adata_5.obsm['spatial']
# Out:
# array([[ 460.81739114,  496.33416456],
#        [ 429.59726857,  530.88714714],
#        [ 442.78118634,  521.2766118 ],
#        ...,
#        [ 743.90551351, 3116.28731081],
#        [ 583.29499783, 2591.38903261],
#        [ 635.75551905, 2452.43248095]])
